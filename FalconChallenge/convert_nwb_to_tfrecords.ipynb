# %%
from pathlib import Path

import numpy as np
import tensorflow as tf
from neuralDecoder.datasets.handwritingDataset import CHAR_DEF

from nwb_utils import *

BIN_SIZE_S = 0.02

# %%
def convertToTFRecord(inputFeats, transcriptions, outputDir):
    nClasses = 31
    maxSeqLen = 500

    def _charToId(char):
        return CHAR_DEF.index(char)

    def _convert_to_ascii(text):
        return [ord(char) for char in text]

    def _floats_feature(value):
        return tf.train.Feature(float_list=tf.train.FloatList(value=value))

    def _ints_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=value))

    saveDir = Path(outputDir)
    saveDir.mkdir(parents=True, exist_ok=True)

    with tf.io.TFRecordWriter(str(saveDir.joinpath("chunk_0.tfrecord"))) as writer:
        for trialIdx in np.arange(len(inputFeats)):
            feats = inputFeats[trialIdx]

            classLabels = np.zeros([feats.shape[0], nClasses]).astype(np.float32)
            newClassSignal = np.zeros([feats.shape[0], 1]).astype(np.float32)
            seqClassIDs = np.zeros([maxSeqLen]).astype(np.int32)

            thisTranscription = transcriptions[trialIdx]

            seqLen = len(thisTranscription)
            seqClassIDs[0:seqLen] = [_charToId(c) + 1 for c in thisTranscription]

            ceMask = np.zeros([feats.shape[0]]).astype(np.float32)

            paddedTranscription = np.zeros([maxSeqLen]).astype(np.int32)
            paddedTranscription[0 : len(thisTranscription)] = np.array(
                _convert_to_ascii(thisTranscription)
            )

            feature = {
                "inputFeatures": _floats_feature(np.ravel(feats).tolist()),
                "classLabelsOneHot": _floats_feature(np.ravel(classLabels).tolist()),
                "newClassSignal": _floats_feature(np.ravel(newClassSignal).tolist()),
                "seqClassIDs": _ints_feature(seqClassIDs),
                "nTimeSteps": _ints_feature([feats.shape[0]]),
                "nSeqElements": _ints_feature([seqLen]),
                "ceMask": _floats_feature(np.ravel(ceMask).tolist()),
                "transcription": _ints_feature(paddedTranscription),
            }

            if trialIdx % 10 == 0:
                print(thisTranscription)
                print(seqClassIDs[0:10])
            example = tf.train.Example(features=tf.train.Features(feature=feature))
            writer.write(example.SerializeToString())

# %%
partitions = Path("nwb").glob("*")
for part in partitions:
    print(part)
    for fn in part.glob("*.nwb"):
        spikes, time, tinfo, eval_mask, _ = load_nwb(fn)
        print(f"Number of trials: {tinfo.shape[0]}")
    print()
# Out:
# nwb/held_out_calib
# Loading nwb/held_out_calib/T5_2023.06.28_held_out_calib.nwb
# Number of trials: 3
# Loading nwb/held_out_calib/T5_2023.08.16_held_out_calib.nwb
# Number of trials: 3
# Loading nwb/held_out_calib/T5_2023.04.17_held_out_calib.nwb
# Number of trials: 3
# Loading nwb/held_out_calib/T5_2023.10.09_held_out_calib.nwb
# Number of trials: 3
# Loading nwb/held_out_calib/T5_2023.05.31_held_out_calib.nwb
# Number of trials: 3
#
# nwb/held_out_eval
# Loading nwb/held_out_eval/T5_2023.06.28_held_out_eval.nwb
# Number of trials: 16
# Loading nwb/held_out_eval/T5_2023.05.31_held_out_eval.nwb
# Number of trials: 16
# Loading nwb/held_out_eval/T5_2023.08.16_held_out_eval.nwb
# Number of trials: 16
# Loading nwb/held_out_eval/T5_2023.04.17_held_out_eval.nwb
# Number of trials: 16
# Loading nwb/held_out_eval/T5_2023.10.09_held_out_eval.nwb
# Number of trials: 16
#
# nwb/held_in_eval
# Loading nwb/held_in_eval/T5_2022.06.03_held_in_eval.nwb
# Number of trials: 32
# Loading nwb/held_in_eval/T5_2022.06.01_held_in_eval.nwb
# Number of trials: 32
# Loading nwb/held_in_eval/T5_2022.06.22_held_in_eval.nwb
# Number of trials: 32
# Loading nwb/held_in_eval/T5_2022.12.08_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.09.01_held_in_eval.nwb
# Number of trials: 20
# Loading nwb/held_in_eval/T5_2022.10.25_held_in_eval.nwb
# Number of trials: 14
# Loading nwb/held_in_eval/T5_2022.06.06_held_in_eval.nwb
# Number of trials: 31
# Loading nwb/held_in_eval/T5_2022.10.27_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.11.01_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.06.08_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.10.06_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.12.15_held_in_eval.nwb
# Number of trials: 8
# Loading nwb/held_in_eval/T5_2022.05.25_held_in_eval.nwb
# Number of trials: 24
# Loading nwb/held_in_eval/T5_2022.10.18_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.06.15_held_in_eval.nwb
# Number of trials: 24
# Loading nwb/held_in_eval/T5_2023.02.28_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.05.18_held_in_eval.nwb
# Number of trials: 20
# Loading nwb/held_in_eval/T5_2022.11.03_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.06.13_held_in_eval.nwb
# Number of trials: 32
# Loading nwb/held_in_eval/T5_2022.09.29_held_in_eval.nwb
# Number of trials: 16
# Loading nwb/held_in_eval/T5_2022.05.23_held_in_eval.nwb
# Number of trials: 32
#
# nwb/held_in_calib
# Loading nwb/held_in_calib/T5_2022.06.15_held_in_calib.nwb
# Number of trials: 36
# Loading nwb/held_in_calib/T5_2022.06.01_held_in_calib.nwb
# Number of trials: 48
# Loading nwb/held_in_calib/T5_2022.11.01_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.10.27_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.06.08_held_in_calib.nwb
# Number of trials: 25
# Loading nwb/held_in_calib/T5_2022.05.23_held_in_calib.nwb
# Number of trials: 48
# Loading nwb/held_in_calib/T5_2022.10.06_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.05.18_held_in_calib.nwb
# Number of trials: 30
# Loading nwb/held_in_calib/T5_2022.06.22_held_in_calib.nwb
# Number of trials: 48
# Loading nwb/held_in_calib/T5_2022.06.03_held_in_calib.nwb
# Number of trials: 48
# Loading nwb/held_in_calib/T5_2022.06.13_held_in_calib.nwb
# Number of trials: 48
# Loading nwb/held_in_calib/T5_2022.12.08_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.11.03_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.06.06_held_in_calib.nwb
# Number of trials: 47
# Loading nwb/held_in_calib/T5_2022.09.29_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.10.25_held_in_calib.nwb
# Number of trials: 23
# Loading nwb/held_in_calib/T5_2023.02.28_held_in_calib.nwb
# Number of trials: 24
# Loading nwb/held_in_calib/T5_2022.12.15_held_in_calib.nwb
# Number of trials: 12
# Loading nwb/held_in_calib/T5_2022.09.01_held_in_calib.nwb
# Number of trials: 30
# Loading nwb/held_in_calib/T5_2022.05.25_held_in_calib.nwb
# Number of trials: 36
# Loading nwb/held_in_calib/T5_2022.10.18_held_in_calib.nwb
# Number of trials: 24
#
# nwb/held_in_minival
# Loading nwb/held_in_minival/T5_2022.05.25_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.12.15_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.12.08_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.13_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.10.25_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.10.27_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.01_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.09.01_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.03_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.05.18_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.06_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2023.02.28_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.15_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.11.03_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.22_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.10.18_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.11.01_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.09.29_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.06.08_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.05.23_held_in_minival.nwb
# Number of trials: 2
# Loading nwb/held_in_minival/T5_2022.10.06_held_in_minival.nwb
# Number of trials: 2
#
# nwb/held_out_oracle
# Loading nwb/held_out_oracle/T5_2023.10.09_held_out_oracle.nwb
# Number of trials: 24
# Loading nwb/held_out_oracle/T5_2023.05.31_held_out_oracle.nwb
# Number of trials: 24
# Loading nwb/held_out_oracle/T5_2023.04.17_held_out_oracle.nwb
# Number of trials: 24
# Loading nwb/held_out_oracle/T5_2023.08.16_held_out_oracle.nwb
# Number of trials: 24
# Loading nwb/held_out_oracle/T5_2023.06.28_held_out_oracle.nwb
# Number of trials: 24

# %% [markdown]
# # Convert seed model training data

# %%
train_nwbs = sorted(Path("nwb/held_in_calib").glob("*.nwb"))
test_nwbs = sorted(Path("nwb/held_in_eval").glob("*.nwb"))

for train_nwb, test_nwb in zip(train_nwbs, test_nwbs):
    train_spikes, train_time, train_tinfo, _, session_date = load_nwb(train_nwb)
    test_spikes, test_time, test_tinfo, _, _ = load_nwb(test_nwb)
    print(
        f"Number of train trials: {train_tinfo.shape[0]}, test trials: {test_tinfo.shape[0]}, val trials: {val_tinfo.shape[0]}"
    )

    # Extract trials
    train_feats, train_cues, train_block_stats = extract_trials(
        train_spikes, train_time, train_tinfo
    )
    test_feats, test_cues, _ = extract_trials(test_spikes, test_time, test_tinfo)

    cpm = np.sum([len(c) for c in train_cues]) / (
        np.sum([f.shape[0] for f in train_feats]) * BIN_SIZE_S / 60
    )
    print(f"Characters per minute: {cpm}")

    # Convert to tfrecords
    convertToTFRecord(
        train_feats[:-2],
        train_cues[:-2],
        f"data/held_in_tfrecords/{session_date}/train",
    )
    convertToTFRecord(
        test_feats,
        test_cues,
        f"data/held_in_tfrecords/{session_date}/eval",
    )
    convertToTFRecord(
        train_feats[-2:],
        train_cues[-2:],
        f"data/held_in_tfrecords/{session_date}/test",
    )
# Out:
# Loading nwb/held_in_calib/T5_2022.05.18_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.05.18_held_in_eval.nwb
# Number of train trials: 30, test trials: 20, val trials: 2
# Characters per minute: 42.74138775252326
# there>just>might>be>too>many>people>there~
# [20  8  5 18  5 27 10 21 19 20]
# three>weeks
# [20  8 18  5  5 27 23  5  5 11]
# why>did>i>have>to>fall>for>a>suicidal>maniac?
# [23  8 25 27  4  9  4 27  9 27]
# is>the>baby>coming>down>with>something>nasty?
# [ 9 19 27 20  8  5 27  2  1  2]
# she>was>a>terrible>woman~
# [19  8  5 27 23  1 19 27  1 27]
# hot>weather
# [ 8 15 20 27 23  5  1 20  8  5]
# Loading nwb/held_in_calib/T5_2022.05.23_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.05.23_held_in_eval.nwb
# Number of train trials: 48, test trials: 32, val trials: 2
# Characters per minute: 34.80892222294418
# stay>home
# [19 20  1 25 27  8 15 13  5  0]
# it>was>quite>a>sight~
# [ 9 20 27 23  1 19 27 17 21  9]
# i>know>you>have>ambitions>to>enter>politics~
# [ 9 27 11 14 15 23 27 25 15 21]
# last>month
# [12  1 19 20 27 13 15 14 20  8]
# last>time
# [12  1 19 20 27 20  9 13  5  0]
# need>to>know
# [14  5  5  4 27 20 15 27 11 14]
# east>of>china
# [ 5  1 19 20 27 15  6 27  3  8]
# pardon>me
# [16  1 18  4 15 14 27 13  5  0]
# the>wording>of>the>title>sounds>reassuring~
# [20  8  5 27 23 15 18  4  9 14]
# zen>garden
# [26  5 14 27  7  1 18  4  5 14]
# Loading nwb/held_in_calib/T5_2022.05.25_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.05.25_held_in_eval.nwb
# Number of train trials: 36, test trials: 24, val trials: 2
# Characters per minute: 32.51821694370251
# keep>it
# [11  5  5 16 27  9 20  0  0  0]
# the>ducks>scattered,>and>the>dog>watched>them>go~
# [20  8  5 27  4 21  3 11 19 27]
# i'm>cooking>vegetable>curry>for>them~
# [ 9 29 13 27  3 15 15 11  9 14]
# good>morning,>everyone~
# [ 7 15 15  4 27 13 15 18 14  9]
# it>was>time>for>a>last>desperate>gamble~
# [ 9 20 27 23  1 19 27 20  9 13]
# let>me>see
# [12  5 20 27 13  5 27 19  5  5]
# he>required>a>minimum>of>fifty>yards>for>safety~
# [ 8  5 27 18  5 17 21  9 18  5]
# mike>never>travels>without>cash>and>credit>cards~
# [13  9 11  5 27 14  5 22  5 18]
# Loading nwb/held_in_calib/T5_2022.06.01_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.01_held_in_eval.nwb
# Number of train trials: 48, test trials: 32, val trials: 2
# Characters per minute: 35.29703061093483
# eagle>nest
# [ 5  1  7 12  5 27 14  5 19 20]
# the>agent>on>my>third>trip>was>a>young>woman~
# [20  8  5 27  1  7  5 14 20 27]
# snow>is>cold
# [19 14 15 23 27  9 19 27  3 15]
# i>never>heard>what>anne>thought>about>it>all~
# [ 9 27 14  5 22  5 18 27  8  5]
# the>choice>was>not>altogether>fortuitous~
# [20  8  5 27  3  8 15  9  3  5]
# exact>date
# [ 5 24  1  3 20 27  4  1 20  5]
# the>world
# [20  8  5 27 23 15 18 12  4  0]
# spencer>smiled>and>turned>back>into>the>room~
# [19 16  5 14  3  5 18 27 19 13]
# six>hours
# [19  9 24 27  8 15 21 18 19  0]
# tell>me>yes
# [20  5 12 12 27 13  5 27 25  5]
# Loading nwb/held_in_calib/T5_2022.06.03_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.03_held_in_eval.nwb
# Number of train trials: 48, test trials: 32, val trials: 2
# Characters per minute: 56.608318612493974
# i>dumped>the>tools>in>the>hut~
# [ 9 27  4 21 13 16  5  4 27 20]
# at>home
# [ 1 20 27  8 15 13  5  0  0  0]
# the>elder>boys>are>not>deterred,>however~
# [20  8  5 27  5 12  4  5 18 27]
# they're>borrowed>from>the>costume>store~
# [20  8  5 25 29 18  5 27  2 15]
# i>can't>say
# [ 9 27  3  1 14 29 20 27 19  1]
# he>fell>behind
# [ 8  5 27  6  5 12 12 27  2  5]
# he>didn't>like>being>tied>up>to>the>women~
# [ 8  5 27  4  9  4 14 29 20 27]
# it>was>simply>too>far>and>too>spread>out~
# [ 9 20 27 23  1 19 27 19  9 13]
# he>hesitated>for>a>moment>before>replying~
# [ 8  5 27  8  5 19  9 20  1 20]
# keep>in>touch
# [11  5  5 16 27  9 14 27 20 15]
# Loading nwb/held_in_calib/T5_2022.06.06_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.06_held_in_eval.nwb
# Number of train trials: 47, test trials: 31, val trials: 2
# Characters per minute: 65.69521872425081
# seven>more>missions>was>required>for>them>to>complete>their>tour~
# [19  5 22  5 14 27 13 15 18  5]
# a>mad>boxer>shot>a>quick,>gloved>jab>to>the>jaw>of>his>dizzy>opponent~
# [ 1 27 13  1  4 27  2 15 24  5]
# with>a>sigh>of>relief>paige>eased>the>weight>from>her>ankle~
# [23  9 20  8 27  1 27 19  9  7]
# she>was>convinced>that>he>was>being>undervalued>and>underestimated~
# [19  8  5 27 23  1 19 27  3 15]
# every>effort>has>been>made>to>produce>an>accurate>list~
# [ 5 22  5 18 25 27  5  6  6 15]
# the>super>bowl>is>in>houston,>and>texas>doesn't>collect>income>tax~
# [20  8  5 27 19 21 16  5 18 27]
# or>do>they>just>move>on,>looking>for>fresh>fields>and>pastures>new>to>flood?
# [15 18 27  4 15 27 20  8  5 25]
# the>movement>attracted>widespread>support>from>peace>campaigners~
# [20  8  5 27 13 15 22  5 13  5]
# my>parents>went>to>visit>mahlon>and>maggie>and>the>children~
# [13 25 27 16  1 18  5 14 20 19]
# lady>montague>dies>of>grief>at>romeo's>banishment?
# [12  1  4 25 27 13 15 14 20  1]
# Loading nwb/held_in_calib/T5_2022.06.08_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.08_held_in_eval.nwb
# Number of train trials: 25, test trials: 16, val trials: 2
# Characters per minute: 55.380122512939835
# their>patient>was>still>alive>but>his>condition>was>deteriorating>visibly~
# [20  8  5  9 18 27 16  1 20  9]
# i>walked>back>to>the>bar>and>wasted>time>with>the>barman~
# [ 9 27 23  1 12 11  5  4 27  2]
# do>you>wish>us>to>inform>your>father>about>what's>happened?
# [ 4 15 27 25 15 21 27 23  9 19]
# this>fuzzy,>probabilistic>approach>is>a>sensible>one~
# [20  8  9 19 27  6 21 26 26 25]
# newman>held>the>automatic>in>the>palm>of>his>hand~
# [14  5 23 13  1 14 27  8  5 12]
# people>forget>that>the>internet>is>a>physical>thing~
# [16  5 15 16 12  5 27  6 15 18]
# Loading nwb/held_in_calib/T5_2022.06.13_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.13_held_in_eval.nwb
# Number of train trials: 48, test trials: 32, val trials: 2
# Characters per minute: 60.12285854589592
# not>even>all>the>brokerage>firms>see>clear>sailing>ahead~
# [14 15 20 27  5 22  5 14 27  1]
# the>average>american>watches>seven>hours>of>tv>a>day~
# [20  8  5 27  1 22  5 18  1  7]
# it's>better>to>wait~
# [ 9 20 29 19 27  2  5 20 20  5]
# the>sale>of>southern>optical>is>a>part>of>the>program~
# [20  8  5 27 19  1 12  5 27 15]
# most>earn>high>ratings>from>credit>agencies~
# [13 15 19 20 27  5  1 18 14 27]
# the>company>reported>a>big>thirdquarter>loss>on>thursday~
# [20  8  5 27  3 15 13 16  1 14]
# they>ought>to>be>able>to>do>this~
# [20  8  5 25 27 15 21  7  8 20]
# moreover>sports>is>hardly>the>best>way>to>lure>adult>women~
# [13 15 18  5 15 22  5 18 27 19]
# in>other>commodity>markets>yesterday~
# [ 9 14 27 15 20  8  5 18 27  3]
# productivity>in>japanese>offices>is>relatively>low~
# [16 18 15  4 21  3 20  9 22  9]
# Loading nwb/held_in_calib/T5_2022.06.15_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.15_held_in_eval.nwb
# Number of train trials: 36, test trials: 24, val trials: 2
# Characters per minute: 56.94129503653313
# the>percentage>change>is>since>yearend~
# [20  8  5 27 16  5 18  3  5 14]
# it's>good>exercise>he>says~
# [ 9 20 29 19 27  7 15 15  4 27]
# but>these>players>were>dead~
# [ 2 21 20 27 20  8  5 19  5 27]
# but>east>germany>is>merely>the>land>of>truly>existing>socialism~
# [ 2 21 20 27  5  1 19 20 27  7]
# she>added>however>it>is>not>robust>by>any>means~
# [19  8  5 27  1  4  4  5  4 27]
# they>are>nonetheless>high>on>manville's>management~
# [20  8  5 25 27  1 18  5 27 14]
# questions>like>that>really>stir>up>marshall's>ghost~
# [17 21  5 19 20  9 15 14 19 27]
# how>was>the>west>won?
# [ 8 15 23 27 23  1 19 27 20  8]
# Loading nwb/held_in_calib/T5_2022.06.22_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.06.22_held_in_eval.nwb
# Number of train trials: 48, test trials: 32, val trials: 2
# Characters per minute: 63.761886853274596
# the>overcast>was>solid>above>him~
# [20  8  5 27 15 22  5 18  3  1]
# property>sales>assistance
# [16 18 15 16  5 18 20 25 27 19]
# why>won't>you>accept>facts?
# [23  8 25 27 23 15 14 29 20 27]
# i>was>held>up>a>bit>trying>to>make>a>left>turn~
# [ 9 27 23  1 19 27  8  5 12  4]
# the>help>and>sympathy>that>were>forthcoming>from>everywhere~
# [20  8  5 27  8  5 12 16 27  1]
# the>new>birth>is>effected>through>the>word>of>god
# [20  8  5 27 14  5 23 27  2  9]
# but>she>clung>to>the>rocks>and>brush,>and>the>day>wore>away~
# [ 2 21 20 27 19  8  5 27  3 12]
# i'll>be>shootin'>right>back~
# [ 9 29 12 12 27  2  5 27 19  8]
# and>it>was>not>pile>of>clouds>she>meant~
# [ 1 14  4 27  9 20 27 23  1 19]
# pat>o'dwyer>looked>like>a>heavier>jim~
# [16  1 20 27 15 29  4 23 25  5]
# Loading nwb/held_in_calib/T5_2022.09.01_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.09.01_held_in_eval.nwb
# Number of train trials: 30, test trials: 20, val trials: 2
# Characters per minute: 68.01198512689074
# jars>are>assembled>in>bowl>of>butter>mold~
# [10  1 18 19 27  1 18  5 27  1]
# enemy>reinforcements>came>pouring>down,>seeking>a>soft>spot~
# [ 5 14  5 13 25 27 18  5  9 14]
# when>the>neon>sign>faded>out,>the>shadow>disappeared~
# [23  8  5 14 27 20  8  5 27 14]
# the>hated>dictator>batista>had>fled~
# [20  8  5 27  8  1 20  5  4 27]
# thankful>i>wasn't>nadine~
# [20  8  1 14 11  6 21 12 27  9]
# her>husband>was>lying>on>the>kitchen>floor,>police>said~
# [ 8  5 18 27  8 21 19  2  1 14]
# Loading nwb/held_in_calib/T5_2022.09.29_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.09.29_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 57.32292917166867
# what>targets>still>remain>to>be>hit?
# [23  8  1 20 27 20  1 18  7  5]
# i'm>not>trying>to>worry>you~
# [ 9 29 13 27 14 15 20 27 20 18]
# i>been>riding>train>for>a>ways>now~
# [ 9 27  2  5  5 14 27 18  9  4]
# it>was>nothing>to>him>if>rain>fell>and>nobody>came~
# [ 9 20 27 23  1 19 27 14 15 20]
# but>this>year>prospects>may>be>better~
# [ 2 21 20 27 20  8  9 19 27 25]
# then>the>nigger>boy>turned>back>and>he>was>alone~
# [20  8  5 14 27 20  8  5 27 14]
# Loading nwb/held_in_calib/T5_2022.10.06_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.10.06_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 63.994474127948315
# now>it>would>have>another>death~
# [14 15 23 27  9 20 27 23 15 21]
# trains>whistling>in>the>night,>the>rattle>and>clatter>of>cabs~
# [20 18  1  9 14 19 27 23  8  9]
# after>a>day>at>nikko,>mrs~>kodama>put>me>on>the>train>for>kyoto~
# [ 1  6 20  5 18 27  1 27  4  1]
# got>a>new>one>in>last>night,>he>said~
# [ 7 15 20 27  1 27 14  5 23 27]
# there>wasn't>any>such>thing>any>more~
# [20  8  5 18  5 27 23  1 19 14]
# they>appeared>to>be>the>enemy~
# [20  8  5 25 27  1 16 16  5  1]
# Loading nwb/held_in_calib/T5_2022.10.18_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.10.18_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 74.4328751238132
# that'll>get>you>started~
# [20  8  1 20 29 12 12 27  7  5]
# you>shall>see>her>at>dinner~
# [25 15 21 27 19  8  1 12 12 27]
# i>guess>i'll>find>out>soon>enough~
# [ 9 27  7 21  5 19 19 27  9 29]
# he>wiped>the>blood>from>his>cheek~
# [ 8  5 27 23  9 16  5  4 27 20]
# the>secretary>was>uneasy>about>the>visit~
# [20  8  5 27 19  5  3 18  5 20]
# we're>all>god's>creatures,>aren't>we?
# [23  5 29 18  5 27  1 12 12 27]
# Loading nwb/held_in_calib/T5_2022.10.25_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.10.25_held_in_eval.nwb
# Number of train trials: 23, test trials: 14, val trials: 2
# Characters per minute: 83.6076188420655
# it>is>really>the>funeral>day>of>scholastic>science~
# [ 9 20 27  9 19 27 18  5  1 12]
# tolley>had>gone>to>live>in>california~
# [20 15 12 12  5 25 27  8  1  4]
# having>all>the>guns>makes>you>a>big>man,>don't>it,>adams?
# [ 8  1 22  9 14  7 27  1 12 12]
# if>you>will>promise>to>make>it>weak~
# [ 9  6 27 25 15 21 27 23  9 12]
# once>you>get>the>feel>of>it,>there's>not>much>to>it~
# [15 14  3  5 27 25 15 21 27  7]
# to>his>faint>surprise>russ>held>up>his>hand~
# [20 15 27  8  9 19 27  6  1  9]
# Loading nwb/held_in_calib/T5_2022.10.27_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.10.27_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 83.19922755069199
# carl>was>still>charles>a~>sandburg~
# [ 3  1 18 12 27 23  1 19 27 19]
# she>was>just>not>able>to>break>the>spell~
# [19  8  5 27 23  1 19 27 10 21]
# stevie>could>feel>himself>toppling~
# [19 20  5 22  9  5 27  3 15 21]
# and>it>is>to>this>problem>that>the>republic>ultimately>returns~
# [ 1 14  4 27  9 20 27  9 19 27]
# there>the>objective>sat,>brooding>over>all~
# [20  8  5 18  5 27 20  8  5 27]
# this>is>drama>enough~
# [20  8  9 19 27  9 19 27  4 18]
# Loading nwb/held_in_calib/T5_2022.11.01_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.11.01_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 74.93282913722759
# she>had>on>her>easter>suit,>blue,>with>lavender>binding~
# [19  8  5 27  8  1  4 27 15 14]
# he>didn't>live>in>a>world>of>perpetual>peril>like>ours~
# [ 8  5 27  4  9  4 14 29 20 27]
# dear>god,>at>what>a>price~
# [ 4  5  1 18 27  7 15  4 28 27]
# she>asked,>winking>wildly~
# [19  8  5 27  1 19 11  5  4 28]
# there>might>be>a>story>in>it~
# [20  8  5 18  5 27 13  9  7  8]
# harvey>b~>stevens>of>kenilworth>will>give>his>niece>in>marriage~
# [ 8  1 18 22  5 25 27  2 30 27]
# Loading nwb/held_in_calib/T5_2022.11.03_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.11.03_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 67.16767388444127
# news>of>the>project>reached>the>press~
# [14  5 23 19 27 15  6 27 20  8]
# you>mustn't>take>a>fall,>or>publicly>back>away~
# [25 15 21 27 13 21 19 20 14 29]
# it>will>be>painted>to>match>the>paneling>in>the>room~
# [ 9 20 27 23  9 12 12 27  2  5]
# if>mankind>could>be>convinced>of>that
# [ 9  6 27 13  1 14 11  9 14  4]
# he>sat>down>on>the>bed~
# [ 8  5 27 19  1 20 27  4 15 23]
# but>no>one>was>overly>optimistic~
# [ 2 21 20 27 14 15 27 15 14  5]
# Loading nwb/held_in_calib/T5_2022.12.08_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.12.08_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 68.50662121410778
# i>should>have>stayed>at>the>store,>she>thought~
# [ 9 27 19  8 15 21 12  4 27  8]
# the>images>can>easily>be>aligned>with>a>high>degree>of>accuracy~
# [20  8  5 27  9 13  1  7  5 19]
# we>shook>hands>on>it~
# [23  5 27 19  8 15 15 11 27  8]
# let>not>your>heart>be>troubled,>neither>let>it>be>afraid~
# [12  5 20 27 14 15 20 27 25 15]
# you>reckon>there's>two>men>in>this>state>can>shoot>like>that?
# [25 15 21 27 18  5  3 11 15 14]
# in>the>past>the>club>depended>largely>on>van>brocklin's>aerials~
# [ 9 14 27 20  8  5 27 16  1 19]
# Loading nwb/held_in_calib/T5_2022.12.15_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2022.12.15_held_in_eval.nwb
# Number of train trials: 12, test trials: 8, val trials: 2
# Characters per minute: 66.24174823582972
# no,>really,>right>as>rain~
# [14 15 28 27 18  5  1 12 12 25]
# fan>it,>he>told>cappy,>handing>him>a>sheet>of>newspaper~
# [ 6  1 14 27  9 20 28 27  8  5]
# the>analyst>is>apt>to>be>too>honest>to>fit>in~
# [20  8  5 27  1 14  1 12 25 19]
# Loading nwb/held_in_calib/T5_2023.02.28_held_in_calib.nwb
# Loading nwb/held_in_eval/T5_2023.02.28_held_in_eval.nwb
# Number of train trials: 24, test trials: 16, val trials: 2
# Characters per minute: 71.26750939528527
# when>alexander>brandel>rose>to>speak,>the>hall>became>silent~
# [23  8  5 14 27  1 12  5 24  1]
# clayton>tried>to>call>back>the>face>of>the>man>he>had>known~
# [ 3 12  1 25 20 15 14 27 20 18]
# the>guerrillas>realized>they>faced>a>new>problem~
# [20  8  5 27  7 21  5 18 18  9]
# purification>of>the>conjugates
# [16 21 18  9  6  9  3  1 20  9]
# during>his>journey>palfrey>stopped>off>to>see>two>abolitionists~
# [ 4 21 18  9 14  7 27  8  9 19]
# but>if>you>say>you>managed>it>the>stranger>was>hooked~
# [ 2 21 20 27  9  6 27 25 15 21]

# %% [markdown]
# # Convert held-out data

# %%
train_nwbs = sorted(Path("nwb/held_out_calib").glob("*.nwb"))
test_nwbs = sorted(Path("nwb/held_out_eval").glob("*.nwb"))
oracle_nwbs = sorted(Path("nwb/held_out_oracle").glob("*.nwb"))

for train_nwb, test_nwb, oracle_nwb in zip(train_nwbs, test_nwbs, oracle_nwbs):
    train_spikes, train_time, train_tinfo, _, session_date = load_nwb(train_nwb)
    test_spikes, test_time, test_tinfo, _, _ = load_nwb(test_nwb)
    oracle_spikes, oracle_time, oracle_tinfo, _, _ = load_nwb(oracle_nwb)
    print(
        f"Number of train trials: {train_tinfo.shape[0]}, test trials: {test_tinfo.shape[0]}, oracle trials: {oracle_tinfo.shape[0]}"
    )

    # Extract trials
    train_feats, train_cues, train_block_stats = extract_trials(
        train_spikes, train_time, train_tinfo
    )
    test_feats, test_cues, _ = extract_trials(
        test_spikes, test_time, test_tinfo
    )
    oracle_feats, oracle_cues, _ = extract_trials(
        oracle_spikes, oracle_time, oracle_tinfo
    )

    # Convert to tfrecords
    # For notebook demo
    convertToTFRecord(
        train_feats,
        train_cues,
        f"data/held_out_demo_tfrecords/{session_date}/test",
    )

    # For few-shot learning
    convertToTFRecord(
        train_feats,
        train_cues,
        f"data/held_out_tfrecords/{session_date}/train",
    )
    convertToTFRecord(
        test_feats,
        test_cues,
        f"data/held_out_tfrecords/{session_date}/test",
    )

    # For oracle eval
    convertToTFRecord(
        oracle_feats,
        oracle_cues,
        f"data/held_out_oracle_tfrecords/{session_date}/train",
    )
    convertToTFRecord(
        test_feats,
        test_cues,
        f"data/held_out_oracle_tfrecords/{session_date}/test",
    )
# Out:
# Loading nwb/held_out_calib/T5_2023.04.17_held_out_calib.nwb
# Loading nwb/held_out_eval/T5_2023.04.17_held_out_eval.nwb
# Loading nwb/held_out_oracle/T5_2023.04.17_held_out_oracle.nwb
# Number of train trials: 3, test trials: 16, oracle trials: 24
# what>about>transfers?
# [23  8  1 20 27  1  2 15 21 20]
# what>about>transfers?
# [23  8  1 20 27  1  2 15 21 20]
# so>he>wound>up>with>a>dozen~
# [19 15 27  8  5 27 23 15 21 14]
# must>or>should>the>federal>government>help?
# [13 21 19 20 27 15 18 27 19  8]
# what>about>transfers?
# [23  8  1 20 27  1  2 15 21 20]
# maris>sleeps>on>a>green>studio>couch>in>the>living>room~
# [13  1 18  9 19 27 19 12  5  5]
# the>figure>halted,>and>watson>gasped~
# [20  8  5 27  6  9  7 21 18  5]
# so>he>wound>up>with>a>dozen~
# [19 15 27  8  5 27 23 15 21 14]
# must>or>should>the>federal>government>help?
# [13 21 19 20 27 15 18 27 19  8]
# Loading nwb/held_out_calib/T5_2023.05.31_held_out_calib.nwb
# Loading nwb/held_out_eval/T5_2023.05.31_held_out_eval.nwb
# Loading nwb/held_out_oracle/T5_2023.05.31_held_out_oracle.nwb
# Number of train trials: 3, test trials: 16, oracle trials: 24
# we're>all>god's>creatures,>aren't>we,>penny?
# [23  5 29 18  5 27  1 12 12 27]
# we're>all>god's>creatures,>aren't>we,>penny?
# [23  5 29 18  5 27  1 12 12 27]
# or>are>the>eyebrows>more>like>this?
# [15 18 27  1 18  5 27 20  8  5]
# here>was>another>indispensable>tool~
# [ 8  5 18  5 27 23  1 19 27  1]
# we're>all>god's>creatures,>aren't>we,>penny?
# [23  5 29 18  5 27  1 12 12 27]
# when>the>light>went>their>way,>they>went>on>across>the>street~
# [23  8  5 14 27 20  8  5 27 12]
# why>didn't>the>damn>reactionaries>bump>him>off?
# [23  8 25 27  4  9  4 14 29 20]
# or>are>the>eyebrows>more>like>this?
# [15 18 27  1 18  5 27 20  8  5]
# here>was>another>indispensable>tool~
# [ 8  5 18  5 27 23  1 19 27  1]
# Loading nwb/held_out_calib/T5_2023.06.28_held_out_calib.nwb
# Loading nwb/held_out_eval/T5_2023.06.28_held_out_eval.nwb
# Loading nwb/held_out_oracle/T5_2023.06.28_held_out_oracle.nwb
# Number of train trials: 3, test trials: 16, oracle trials: 24
# he>succeeds>buck>shaw,>who>retired>at>the>end>of>last>season~
# [ 8  5 27 19 21  3  3  5  5  4]
# he>succeeds>buck>shaw,>who>retired>at>the>end>of>last>season~
# [ 8  5 27 19 21  3  3  5  5  4]
# that>way>i>don't>lose>so>much~
# [20  8  1 20 27 23  1 25 27  9]
# mr~>blatz>agreed>that>this>would>be>pretty~
# [13 18 30 27  2 12  1 20 26 27]
# he>succeeds>buck>shaw,>who>retired>at>the>end>of>last>season~
# [ 8  5 27 19 21  3  3  5  5  4]
# the>need>of>the>new>birth
# [20  8  5 27 14  5  5  4 27 15]
# dancers>do>have>flexibility~
# [ 4  1 14  3  5 18 19 27  4 15]
# that>way>i>don't>lose>so>much~
# [20  8  1 20 27 23  1 25 27  9]
# mr~>blatz>agreed>that>this>would>be>pretty~
# [13 18 30 27  2 12  1 20 26 27]
# Loading nwb/held_out_calib/T5_2023.08.16_held_out_calib.nwb
# Loading nwb/held_out_eval/T5_2023.08.16_held_out_eval.nwb
# Loading nwb/held_out_oracle/T5_2023.08.16_held_out_oracle.nwb
# Number of train trials: 3, test trials: 16, oracle trials: 24
# we>had>just>sat>down~
# [23  5 27  8  1  4 27 10 21 19]
# we>had>just>sat>down~
# [23  5 27  8  1  4 27 10 21 19]
# how>can>they>tell>whether>a>child>needs>orthodontic>treatment?
# [ 8 15 23 27  3  1 14 27 20  8]
# the>humor>of>the>situation>can>be>imagined~
# [20  8  5 27  8 21 13 15 18 27]
# we>had>just>sat>down~
# [23  5 27  8  1  4 27 10 21 19]
# a>chicken>with>six>tits>and>a>tail>lak>a>corkscrew~
# [ 1 27  3  8  9  3 11  5 14 27]
# neither>is>adequate>if>it>stands>alone~
# [14  5  9 20  8  5 18 27  9 19]
# how>can>they>tell>whether>a>child>needs>orthodontic>treatment?
# [ 8 15 23 27  3  1 14 27 20  8]
# the>humor>of>the>situation>can>be>imagined~
# [20  8  5 27  8 21 13 15 18 27]
# Loading nwb/held_out_calib/T5_2023.10.09_held_out_calib.nwb
# Loading nwb/held_out_eval/T5_2023.10.09_held_out_eval.nwb
# Loading nwb/held_out_oracle/T5_2023.10.09_held_out_oracle.nwb
# Number of train trials: 3, test trials: 16, oracle trials: 24
# at>least>she>never>knew>what>the>bottom>was>like~
# [ 1 20 27 12  5  1 19 20 27 19]
# at>least>she>never>knew>what>the>bottom>was>like~
# [ 1 20 27 12  5  1 19 20 27 19]
# all>capabilities>must>be>used>to>maximum>advantage>then~
# [ 1 12 12 27  3  1 16  1  2  9]
# and>that's>worse>than>sad~
# [ 1 14  4 27 20  8  1 20 29 19]
# at>least>she>never>knew>what>the>bottom>was>like~
# [ 1 20 27 12  5  1 19 20 27 19]
# those>lovely>whorls,>he>chortled~
# [20  8 15 19  5 27 12 15 22  5]
# brannon>said,>now>the>key>to>the>lockup,>marshal~
# [ 2 18  1 14 14 15 14 27 19  1]
# all>capabilities>must>be>used>to>maximum>advantage>then~
# [ 1 12 12 27  3  1 16  1  2  9]
# and>that's>worse>than>sad~
# [ 1 14  4 27 20  8  1 20 29 19]
